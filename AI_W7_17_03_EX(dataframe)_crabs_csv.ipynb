# %% [markdown]
# <a href="https://colab.research.google.com/github/NamNT36/Artifical-Intelligence/blob/main/AI_W7_17_03_EX(dataframe)_crabs_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### BAI 1
# Load library
import pandas as pd 
import numpy as np

# Create URL 
url = 'crabs.csv'

# Load data
data = pd.read_csv(url)

data.head()

correlation = data.corr()
print(correlation)
# Out:
#               index  fontallip  rearwidth    length     width     depth
# index      1.000000   0.862876   0.840040  0.911436  0.928248  0.864459
# fontallip  0.862876   1.000000   0.906988  0.978842  0.964956  0.987627
# rearwidth  0.840040   0.906988   1.000000  0.892743  0.900402  0.889205
# length     0.911436   0.978842   0.892743  1.000000  0.995023  0.983204
# width      0.928248   0.964956   0.900402  0.995023  1.000000  0.967812
# depth      0.864459   0.987627   0.889205  0.983204  0.967812  1.000000

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 

data.hist()
plt.show()

# %%
sns.pairplot(data)

# %%
sns.heatmap(correlation, annot = True)
# Biểu thị bảng dưới màu sắc
# Out:
# <Axes: >

# %%
## width & length -> 0.995023 (in corr)
data.plot(kind = 'scatter', x = 'width', y = 'length', figsize = (9,9),color = 'red')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='width', ylabel='length'>

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X = pd.DataFrame(data['width']), y = data['length']) 
print('Giá trị Interce: ',model.intercept_)
print('Giá trị Coeffient: ',model.coef_)
print('Độ chính xác của mô hình:', model.score(X= pd.DataFrame(data['width']), y = data['length']))
# Out:
# Giá trị Interce:  -0.6619479443406746
# Giá trị Coeffient:  [0.89984616]
# Độ chính xác của mô hình: 0.9900698671905853

# %%
data.plot(kind = 'scatter', x = 'width', y = 'length', figsize = (9,9), color = 'green')
y_pred = model.predict(X = pd.DataFrame(data['width']))  #pred: Mũ
plt.plot(data['width'], y_pred, color = 'blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['width'], data['width']**2, data['width']**3, data['width']**4, data['width']**5,
                  data['width']**6, data['width']**7, data['width']**8, data['width']**9, data['width']**10,
                  data['width']**11]).T
model.fit(X, y = data['length'])
print('Hệ số Intercept:', model.intercept_)
print('Hệ số Coeffient:', model.coef_)
print('Độ chính xác của mô hình:', model.score(X, y = data['length']))
# Out:
# Hệ số Intercept: 11.74968396147812
# Hệ số Coeffient: [ 2.38207284e-10 -4.51780758e-09  1.02981583e-07  1.16153852e-06
#   7.14293248e-06 -2.08384438e-07 -1.90852231e-08  1.31095342e-09
#  -3.27377742e-11  3.79336570e-13 -1.71069193e-15]
# Độ chính xác của mô hình: 0.9903114541204591

# %%
range = np.arange(15, 55, 0.1)
X_range = pd.DataFrame([range,range**2,range**3,range**4,range**5,
                        range**6,range**7,range**8,range**9,range**10,
                        range**11]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'width', y = 'length', figsize = (9,9), color = 'blue', xlim = (10,55))
plt.plot(range, y_pred, color = 'red')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
model.fit(X = data.loc[:,['width','depth','rearwidth','fontallip']], y = data['length'])
print('Hệ số Intercept:', model.intercept_)
print('Hệ số Coeffient:', model.coef_)
print('Độ chính xác của mô hình:', model.score(X = data.loc[:,['width','depth','rearwidth','fontallip']], y = data['length']))
# Out:
# Hệ số Intercept: 0.31633643451032967
# Hệ số Coeffient: [ 0.64021898  0.47141519 -0.17789482  0.26489327]
# Độ chính xác của mô hình: 0.9972880759299462
